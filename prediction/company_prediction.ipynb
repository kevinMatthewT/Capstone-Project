# %% [markdown]
# This page is for testing purposes and not the cleaned version to be used at the end

# %%
import requests
import json

# %%
unfiltered_endpoint="/api/get/investment/Company/filter/"
company_search="Finance Helpers"

url=f"http://localhost:8080{unfiltered_endpoint}{company_search}"

# %%
body=requests.get(url).json()

# %%
import pandas as pd
df=pd.DataFrame(body)

# %%
df.head()
# Out:
#                         _id          Company Company_Investor Domicile  \
# 0  679375886b78f05d3235a0ff  Finance Helpers  Great Investors  Jakarta
# 1  679375896b78f05d3235a100  Finance Helpers  Great Investors  Jakarta
# 2  679375896b78f05d3235a101  Finance Helpers  Great Investors  Jakarta
# 3  679375896b78f05d3235a102  Finance Helpers  Great Investors  Jakarta
# 4  679375896b78f05d3235a103  Finance Helpers  Great Investors  Jakarta
#
#    Year_Of_Operation Business  Percentage_Ownership  Revenue  Expense  \
# 0               2010  Finance                    92  4222414  3337437
# 1               2010  Finance                    68  4501665   532034
# 2               2010  Finance                    73  3953182   719870
# 3               2010  Finance                    63  1186600   760600
# 4               2010  Finance                    11  3156737  2711070
#
#      Ebida  Tax_Investment  Price_Asset  Price_Liability   Equity    COGS  \
# 0   826606          165321      4438855          2320211  2118644   58371
# 1  3886283          777256      6597236          1889735  4707501   83348
# 2  3122599          624519      2758317          1796495   961822  110713
# 3   373668           74733      1515293           619896   895397   52332
# 4   310246           62049      3220980          2151085  1069895  135421
#
#           Date_Of_Ownership  __v
# 0  2024-01-01T00:00:00.000Z    0
# 1  2024-01-02T00:00:00.000Z    0
# 2  2024-01-03T00:00:00.000Z    0
# 3  2024-01-04T00:00:00.000Z    0
# 4  2024-01-05T00:00:00.000Z    0

# %%
df.drop(columns=["_id","__v"],inplace=True, errors='ignore')
df.head(5)
# Out:
#            Company Company_Investor Domicile  Year_Of_Operation Business  \
# 0  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 1  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 2  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 3  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 4  Finance Helpers  Great Investors  Jakarta               2010  Finance
#
#    Percentage_Ownership  Revenue  Expense    Ebida  Tax_Investment  \
# 0                    92  4222414  3337437   826606          165321
# 1                    68  4501665   532034  3886283          777256
# 2                    73  3953182   719870  3122599          624519
# 3                    63  1186600   760600   373668           74733
# 4                    11  3156737  2711070   310246           62049
#
#    Price_Asset  Price_Liability   Equity    COGS         Date_Of_Ownership
# 0      4438855          2320211  2118644   58371  2024-01-01T00:00:00.000Z
# 1      6597236          1889735  4707501   83348  2024-01-02T00:00:00.000Z
# 2      2758317          1796495   961822  110713  2024-01-03T00:00:00.000Z
# 3      1515293           619896   895397   52332  2024-01-04T00:00:00.000Z
# 4      3220980          2151085  1069895  135421  2024-01-05T00:00:00.000Z

# %%
df["Date_Of_Ownership"]=pd.to_datetime(df["Date_Of_Ownership"])
df.head(5)
# Out:
#            Company Company_Investor Domicile  Year_Of_Operation Business  \
# 0  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 1  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 2  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 3  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 4  Finance Helpers  Great Investors  Jakarta               2010  Finance
#
#    Percentage_Ownership  Revenue  Expense    Ebida  Tax_Investment  \
# 0                    92  4222414  3337437   826606          165321
# 1                    68  4501665   532034  3886283          777256
# 2                    73  3953182   719870  3122599          624519
# 3                    63  1186600   760600   373668           74733
# 4                    11  3156737  2711070   310246           62049
#
#    Price_Asset  Price_Liability   Equity    COGS         Date_Of_Ownership
# 0      4438855          2320211  2118644   58371 2024-01-01 00:00:00+00:00
# 1      6597236          1889735  4707501   83348 2024-01-02 00:00:00+00:00
# 2      2758317          1796495   961822  110713 2024-01-03 00:00:00+00:00
# 3      1515293           619896   895397   52332 2024-01-04 00:00:00+00:00
# 4      3220980          2151085  1069895  135421 2024-01-05 00:00:00+00:00

# %%
import matplotlib.pyplot as plt
import matplotlib.dates as mdates
import seaborn as sns

# %%
plt.figure
plt.xlabel("Revenue")
plt.ylabel("Expense")
sns.regplot(x="Revenue",y="Expense", data=df)

plt.show()

# %%
plt.figure
plt.xlabel("Revenue")
plt.ylabel("Ebida")
sns.regplot(x="Revenue",y="Ebida", data=df)

plt.show()

# %%
plt.figure
plt.xlabel("COGS")
plt.ylabel("Revenue")
sns.regplot(x="COGS",y="Revenue", data=df)

plt.show()

# %%
plt.figure
plt.xlabel("Percentage_Ownership")
plt.ylabel("Equity")
sns.regplot(x="Percentage_Ownership",y="Equity", data=df)

plt.show()

# %%
plt.figure
plt.xlabel("Price_Asset")
plt.ylabel("Price_Liability")
sns.regplot(x="Price_Asset",y="Price_Liability", data=df)
 
plt.show()

# %%
plt.figure
plt.xlabel("Year_Of_Operation")
plt.ylabel("Ebida")
sns.regplot(x="Year_Of_Operation",y="Ebida", data=df)
 
plt.show()

# %%
plt.figure
plt.xlabel("Year_Of_Operation")
plt.ylabel("Revenue")
sns.regplot(x="Year_Of_Operation",y="Revenue", data=df)
 
plt.show()

# %%
plt.figure
plt.xlabel("Date_Of_Ownership")
plt.ylabel("Equity")
sns.regplot(x=mdates.date2num(df["Date_Of_Ownership"]),y="Equity", data=df)
 
plt.show()

# %% [markdown]
# PREDICTION MODEL

# %%
from sktime.forecasting.base import ForecastingHorizon
from sktime.forecasting.model_selection import temporal_train_test_split
from sktime.forecasting.theta import ThetaForecaster
from sktime.performance_metrics.forecasting import mean_absolute_percentage_error
from sktime.utils.plotting import plot_series

from sklearn.metrics import mean_absolute_error, r2_score
from prophet import Prophet
import numpy as np

# %%
Company_Name = "Finance Helpers"
Company_Investor_Name = "Great Investors"
Domicile_Name = "Jakarta"

# %%
df_to_predict= df.loc[(df['Company']== Company_Name) & (df['Company_Investor']== Company_Investor_Name) & (df['Domicile']== Domicile_Name) ]
df_to_predict.head(5)
# Out:
#            Company Company_Investor Domicile  Year_Of_Operation Business  \
# 0  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 1  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 2  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 3  Finance Helpers  Great Investors  Jakarta               2010  Finance
# 4  Finance Helpers  Great Investors  Jakarta               2010  Finance
#
#    Percentage_Ownership  Revenue  Expense    Ebida  Tax_Investment  \
# 0                    92  4222414  3337437   826606          165321
# 1                    68  4501665   532034  3886283          777256
# 2                    73  3953182   719870  3122599          624519
# 3                    63  1186600   760600   373668           74733
# 4                    11  3156737  2711070   310246           62049
#
#    Price_Asset  Price_Liability   Equity    COGS         Date_Of_Ownership
# 0      4438855          2320211  2118644   58371 2024-01-01 00:00:00+00:00
# 1      6597236          1889735  4707501   83348 2024-01-02 00:00:00+00:00
# 2      2758317          1796495   961822  110713 2024-01-03 00:00:00+00:00
# 3      1515293           619896   895397   52332 2024-01-04 00:00:00+00:00
# 4      3220980          2151085  1069895  135421 2024-01-05 00:00:00+00:00

# %%
df_to_predict=df_to_predict.set_index(['Date_Of_Ownership'])
df_to_predict=df_to_predict.sort_index()
df_to_predict.index
# Out:
# DatetimeIndex(['2024-01-01 00:00:00+00:00', '2024-01-02 00:00:00+00:00',
#                '2024-01-03 00:00:00+00:00', '2024-01-04 00:00:00+00:00',
#                '2024-01-05 00:00:00+00:00', '2024-01-06 00:00:00+00:00',
#                '2024-01-07 00:00:00+00:00', '2024-01-08 00:00:00+00:00',
#                '2024-01-09 00:00:00+00:00', '2024-01-10 00:00:00+00:00',
#                ...
#                '2024-12-22 00:00:00+00:00', '2024-12-23 00:00:00+00:00',
#                '2024-12-24 00:00:00+00:00', '2024-12-25 00:00:00+00:00',
#                '2024-12-26 00:00:00+00:00', '2024-12-27 00:00:00+00:00',
#                '2024-12-28 00:00:00+00:00', '2024-12-29 00:00:00+00:00',
#                '2024-12-30 00:00:00+00:00', '2024-12-31 00:00:00+00:00'],
#               dtype='datetime64[ns, UTC]', name='Date_Of_Ownership', length=365, freq=None)

# %%
df_to_predict=df_to_predict.reset_index()

# %%
df_to_predict=df_to_predict.drop(["Company","Company_Investor","Domicile","Business","Percentage_Ownership","Year_Of_Operation"], axis=1)
df_to_predict.head(5)
# Out:
#           Date_Of_Ownership  Revenue  Expense    Ebida  Tax_Investment  \
# 0 2024-01-01 00:00:00+00:00  4222414  3337437   826606          165321
# 1 2024-01-02 00:00:00+00:00  4501665   532034  3886283          777256
# 2 2024-01-03 00:00:00+00:00  3953182   719870  3122599          624519
# 3 2024-01-04 00:00:00+00:00  1186600   760600   373668           74733
# 4 2024-01-05 00:00:00+00:00  3156737  2711070   310246           62049
#
#    Price_Asset  Price_Liability   Equity    COGS
# 0      4438855          2320211  2118644   58371
# 1      6597236          1889735  4707501   83348
# 2      2758317          1796495   961822  110713
# 3      1515293           619896   895397   52332
# 4      3220980          2151085  1069895  135421

# %%
df_to_predict=df_to_predict.dropna()
df_to_predict.isna().count()
# Out:
# Date_Of_Ownership    365
# Revenue              365
# Expense              365
# Ebida                365
# Tax_Investment       365
# Price_Asset          365
# Price_Liability      365
# Equity               365
# COGS                 365
# dtype: int64

# %%
df_to_predict['Date_Of_Ownership'] = pd.to_datetime(df_to_predict['Date_Of_Ownership']).dt.tz_localize(None)
df_to_predict2=df_to_predict.copy()

# %%
df_to_predict.head()
# Out:
#   Date_Of_Ownership  Revenue  Expense    Ebida  Tax_Investment  Price_Asset  \
# 0        2024-01-01  4222414  3337437   826606          165321      4438855
# 1        2024-01-02  4501665   532034  3886283          777256      6597236
# 2        2024-01-03  3953182   719870  3122599          624519      2758317
# 3        2024-01-04  1186600   760600   373668           74733      1515293
# 4        2024-01-05  3156737  2711070   310246           62049      3220980
#
#    Price_Liability   Equity    COGS
# 0          2320211  2118644   58371
# 1          1889735  4707501   83348
# 2          1796495   961822  110713
# 3           619896   895397   52332
# 4          2151085  1069895  135421

# %%
days_to_predict = 30

# %%
forecast_results = {}

columns_to_forecast= ['Revenue','Expense','Ebida','Tax_Investment','Price_Asset','Price_Liability','Equity','COGS']

for column in columns_to_forecast:
    # Prepare the data for Prophet
    data = df[['Date_Of_Ownership', column]].rename(columns={'Date_Of_Ownership': 'ds', column: 'y'})
    data['ds'] = pd.to_datetime(data['ds']).dt.tz_localize(None)
    cap_value = data['y'].quantile(0.95)
    data['cap'] = cap_value
    
    model= Prophet(growth='logistic', yearly_seasonality=False, weekly_seasonality=True,daily_seasonality=True)
    model.fit(data)
    
    future = model.make_future_dataframe(periods=days_to_predict, include_history=False)
    future['cap']=cap_value
    
    forecast = model.predict(future)
    
    forecast_results[column] = forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']]
# Out:
# 18:15:52 - cmdstanpy - INFO - Chain [1] start processing
# 18:15:52 - cmdstanpy - INFO - Chain [1] done processing
# 18:15:53 - cmdstanpy - INFO - Chain [1] start processing
# 18:15:53 - cmdstanpy - INFO - Chain [1] done processing
# 18:15:54 - cmdstanpy - INFO - Chain [1] start processing
# 18:15:54 - cmdstanpy - INFO - Chain [1] done processing
# 18:15:55 - cmdstanpy - INFO - Chain [1] start processing
# 18:15:55 - cmdstanpy - INFO - Chain [1] done processing
# 18:15:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:15:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:15:56 - cmdstanpy - INFO - Chain [1] start processing
# 18:15:56 - cmdstanpy - INFO - Chain [1] done processing
# 18:15:57 - cmdstanpy - INFO - Chain [1] start processing
# 18:15:57 - cmdstanpy - INFO - Chain [1] done processing
# 18:15:58 - cmdstanpy - INFO - Chain [1] start processing
# 18:15:58 - cmdstanpy - INFO - Chain [1] done processing

# %%
# Combine forecasts into a single dataframe
combined_forecast = pd.DataFrame({'ds': forecast_results[columns_to_forecast[0]]['ds']})

for column in columns_to_forecast:
    col_forecast = forecast_results[column].rename(columns={
        'yhat': f'{column}_forecast',
        'yhat_lower': f'{column}_lower',
        'yhat_upper': f'{column}_upper'
    })
    combined_forecast = combined_forecast.merge(col_forecast, on='ds')

combined_forecast.head()
# Out:
#           ds  Revenue_forecast  Revenue_lower  Revenue_upper  \
# 0 2025-01-01      2.427541e+06  642210.691828   4.105078e+06
# 1 2025-01-02      2.379849e+06  606301.095191   4.043386e+06
# 2 2025-01-03      2.539769e+06  936764.875924   4.280443e+06
# 3 2025-01-04      2.100127e+06  436562.488460   3.802826e+06
# 4 2025-01-05      2.303899e+06  566111.005082   3.907294e+06
#
#    Expense_forecast  Expense_lower  Expense_upper  Ebida_forecast  \
# 0      1.352997e+06  151891.229469   2.451868e+06    1.018889e+06
# 1      1.280198e+06  153342.621252   2.417677e+06    1.061992e+06
# 2      1.370873e+06  261934.048697   2.424420e+06    1.113786e+06
# 3      1.117568e+06   13788.259152   2.386307e+06    9.456923e+05
# 4      1.089955e+06  -78268.988383   2.213563e+06    1.171330e+06
#
#      Ebida_lower   Ebida_upper  ...  Price_Asset_upper  \
# 0 -236138.530431  2.362043e+06  ...       8.952844e+06
# 1 -268966.172656  2.435707e+06  ...       8.475846e+06
# 2 -179844.536002  2.457651e+06  ...       9.400518e+06
# 3 -345611.082933  2.251565e+06  ...       9.136869e+06
# 4 -217903.213823  2.489836e+06  ...       8.639010e+06
#
#    Price_Liability_forecast  Price_Liability_lower  Price_Liability_upper  \
# 0              2.271323e+06          382222.798809           3.940283e+06
# 1              2.268515e+06          464323.508367           4.130727e+06
# 2              2.563958e+06          746380.051367           4.477403e+06
# 3              2.367911e+06          678517.910044           4.145275e+06
# 4              2.528467e+06          772786.479094           4.325635e+06
#
#    Equity_forecast  Equity_lower  Equity_upper  COGS_forecast    COGS_lower  \
# 0     3.649773e+06  8.590726e+05  6.218118e+06  146563.722130  90994.775236
# 1     3.037863e+06  6.100622e+05  5.566289e+06  128262.338191  67697.293232
# 2     3.765778e+06  1.401343e+06  6.402048e+06  144881.507815  94165.158010
# 3     3.803260e+06  1.264256e+06  6.405484e+06  133940.806730  78799.975201
# 4     2.904999e+06  2.333841e+05  5.287865e+06  134901.953476  79879.002798
#
#       COGS_upper
# 0  201425.191034
# 1  181535.326294
# 2  199517.858638
# 3  185965.163637
# 4  189956.438213
#
# [5 rows x 25 columns]

# %%
import matplotlib.pyplot as plt

for column in columns_to_forecast:
    plt.plot(df_to_predict['Date_Of_Ownership'], df_to_predict[column], label='Actual')
    plt.plot(forecast_results[column]['ds'], forecast_results[column]['yhat'], label='Forecast')
    plt.fill_between(forecast_results[column]['ds'], forecast_results[column]['yhat_lower'], forecast_results[column]['yhat_upper'], alpha=0.2, label='Uncertainty Interval')
    plt.legend()
    plt.show()
